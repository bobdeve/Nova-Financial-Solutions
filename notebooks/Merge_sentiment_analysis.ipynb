# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sys

sys.path.append('../scripts')
from visualization_labeling import process_and_plot_sentiment

companies = [
    {
        "name": "Apple",
        "input": "../datas/AAPL_merged_data.csv",
        "output": "../datas/AAPL_merged_data_labeled.csv"
    },
    {
        "name": "Meta",
        "input": "../datas/META_merged_data.csv",
        "output": "../datas/META_merged_data_labeled.csv"
    },
    {
        "name": "Amazon",
        "input": "../datas/AMZN_merged_data.csv",
        "output": "../datas/AMZN_merged_data_labeled.csv"
    },
    {
        "name": "Google",
        "input": "../datas/GOOG_merged_data.csv",
        "output": "../datas/GOOG_merged_data_labeled.csv"
    },
    {
        "name": "Microsoft",
        "input": "../datas/MSFT_merged_data.csv",
        "output": "../datas/MSFT_merged_data_labeled.csv"
    },
    {
        "name": "NVIDIA",
        "input": "../datas/NVDA_merged_data.csv",
        "output": "../datas/NVDA_merged_data_labeled.csv"
    }
]
for company in companies:
    process_and_plot_sentiment(
        input_path=company["input"],
        output_path=company["output"],
        company_name=company["name"]
    )
# Out:
# c:\Users\Bob\Desktop\10Acadamy\nova\Nova-Financial-Solutions\notebooks\../scripts\visualization_labeling.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=merged_df, x='Sentiment_Label', palette='pastel')
# c:\Users\Bob\Desktop\10Acadamy\nova\Nova-Financial-Solutions\notebooks\../scripts\visualization_labeling.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=merged_df, x='Sentiment_Label', palette='pastel')
# c:\Users\Bob\Desktop\10Acadamy\nova\Nova-Financial-Solutions\notebooks\../scripts\visualization_labeling.py:26: FutureWarning:
#
# ...
